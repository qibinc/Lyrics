# %%
import thulac 
import json

# %%
path = './data/original/lyrics/'

# %%
def read_data(filename):
    with open(filename,'r',encoding='utf-8') as fin:
        #fin = open(filename)
        #remove comment lines
        #for i in range(5):
            #fin.readline()
        data = json.load(fin)
    return data

# %%
thulac.thulac(seg_only=True).cut('')
# Out:
# Model loaded succeed
# []

# %%
len(read_data(path+'val_pairs.json'))
# Out:
# 4184

# %%
len(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c32229b5dda9> in <module>()
# ----> 1 len(data)
#
# NameError: name 'data' is not defined

# %%
data = read_data(path+'test_pairs.json')+read_data(path+'train_pairs.json')+read_data(path+'val_pairs.json')
data
# Out:
# [['怕怕自己做不到', '怕让你伤心'],
#  ['怕让你伤心', '不说了呵呵'],
#  ['不说了呵呵', '原本计划好的'],
#  ['原本计划好的', '唱一个得瑟的歌儿给你听'],
#  ['唱一个得瑟的歌儿给你听', '可是计划果然没有变化快'],
#  ['可是计划果然没有变化快', '等我感冒好了'],
#  ['等我感冒好了', '我还要写一首给你'],
#  ['我还要写一首给你', '好久好久没有写过歌给你了'],
#  ['好久好久没有写过歌给你了', '这样下去会不会有种我要移情别恋的感觉啊'],
#  ['这样下去会不会有种我要移情别恋的感觉啊', '不逗你了阿'],
#  ['不逗你了阿', '生日快乐'],
#  ['生日快乐', '我的臭师傅臭师傅臭师傅'],
#  ['我的臭师傅臭师傅臭师傅', '我爱你'],
#  ['我爱你', '今年'],
#  ['今年', '明年'],
#  ['明年', '后年'],
#  ['后年', '以后的每一年生日'],
#  ['以后的每一年生日', '都想陪你一起过'],
#  ['都想陪你一起过', '我爱你'],
#  ['我爱你', '君伝'],
#  ['君伝', '谏山実生'],
#  ['谏山実生', '诱惑'],
#  ['诱惑', '谏山実生'],
#  ['谏山実生', '君伝'],
#  ['君伝', '闻'],
#  ['闻', '伝事'],
#  ['伝事', '投事言君'],
#  ['投事言君', '谛'],
#  ['谛', '何故生'],
#  ['何故生', '迷事多'],
#  ['迷事多', '进'],
#  ['进', '何度'],
#  ['何度', '転'],
#  ['転', '抱上'],
#  ['抱上', '飞'],
#  ['飞', '颜上'],
#  ['颜上', '闻'],
#  ['闻', '伝事'],
#  ['伝事', '人皆'],
#  ['人皆', '自分弱见'],
#  ['自分弱见', '向合大人'],
#  ['向合大人', '一度'],
#  ['一度', '思切生'],
#  ['思切生', '少多'],
#  ['少多', '歓触'],
#  ['歓触', '何度'],
#  ['何度', '间违'],
#  ['间违', '直'],
#  ['直', '答'],
#  ['答', '分日'],
#  ['分日', '何度'],
#  ['何度', '転'],
#  ['転', '抱上'],
#  ['抱上', '飞'],
#  ['飞', '光中'],
#  ['光中', '有爱就有家'],
#  ['有爱就有家', '杨清明'],
#  ['杨清明', '吉时雨'],
#  ['吉时雨', '有爱就有家'],
#  ['有爱就有家', '演唱杨清明'],
#  ['演唱杨清明', '吉时雨'],
#  ['吉时雨', '我们常常责怪'],
#  ['我们常常责怪', '时间都去哪啦'],
#  ['时间都去哪啦', '岁月斑驳谁又'],
#  ['岁月斑驳谁又', '能把它格式化'],
#  ['能把它格式化', '曾经年少轻狂'],
#  ['曾经年少轻狂', '和荒唐的想法'],
#  ['和荒唐的想法', '都被宽容慢慢'],
#  ['都被宽容慢慢', '慢慢地熔化'],
#  ['慢慢地熔化', '多么温暖的一句话'],
#  ['多么温暖的一句话', '它在我心里'],
#  ['它在我心里', '生根发了芽'],
#  ['生根发了芽', '有爱就有家'],
#  ['有爱就有家', '有爱就有家'],
#  ['有爱就有家', '让我们用心呵护吧'],
#  ['让我们用心呵护吧', '我们常常会问'],
#  ['我们常常会问', '怎样感恩报答'],
#  ['怎样感恩报答', '日月如梭看看'],
#  ['日月如梭看看', '那皱纹刻下的疤'],
#  ['那皱纹刻下的疤', '多少理由借口'],
#  ['多少理由借口', '和心中的想法'],
#  ['和心中的想法', '都被包容识破'],
#  ['都被包容识破', '识破了真假'],
#  ['识破了真假', '多少温馨的一句话'],
#  ['多少温馨的一句话', '伴我走过了'],
#  ['伴我走过了', '春秋和冬夏'],
#  ['春秋和冬夏', '有爱就有家'],
#  ['有爱就有家', '有爱就有家'],
#  ['有爱就有家', '让我们真心对待吧'],
#  ['让我们真心对待吧', '多少温馨的一句话'],
#  ['多少温馨的一句话', '伴我走过了'],
#  ['伴我走过了', '春秋和冬夏'],
#  ['春秋和冬夏', '有爱就有家'],
#  ['有爱就有家', '有爱就有家'],
#  ['有爱就有家', '让我们真心对待吧'],
#  ['让我们真心对待吧', '忽然明白了'],
#  ['忽然明白了', '郑颖芬'],
#  ['郑颖芬', '电视剧金牌律师插曲'],
#  ['电视剧金牌律师插曲', '忽然明白了'],
#  ['忽然明白了', '演唱郑颖芬'],
#  ['演唱郑颖芬', '忽然安静了'],
#  ['忽然安静了', '街道冷清'],
#  ['街道冷清', '天色已晚了吗'],
#  ['天色已晚了吗', '我还站在风中'],
#  ['我还站在风中', '忽然清醒了'],
#  ['忽然清醒了', '不是不懂'],
#  ['不是不懂', '你要离开了吗'],
#  ['你要离开了吗', '我还留在梦中'],
#  ['我还留在梦中', '无法原谅吗'],
#  ['无法原谅吗', '所有误解和冲动'],
#  ['所有误解和冲动', '放任自己'],
#  ['放任自己', '让泪水汹涌'],
#  ['让泪水汹涌', '忽然间明白了'],
#  ['忽然间明白了', '爱有多甜就有多痛'],
#  ['爱有多甜就有多痛', '再多努力'],
#  ['再多努力', '也换不来永恒的爱情'],
#  ['也换不来永恒的爱情', '忽然清醒了'],
#  ['忽然清醒了', '不是不懂'],
#  ['不是不懂', '你要离开了吗'],
#  ['你要离开了吗', '我还留在梦中'],
#  ['我还留在梦中', '无法原谅吗'],
#  ['无法原谅吗', '所有误解和冲动'],
#  ['所有误解和冲动', '放任自己'],
#  ['放任自己', '让泪水汹涌'],
#  ['让泪水汹涌', '忽然间明白了'],
#  ['忽然间明白了', '爱有多甜就有多痛'],
#  ['爱有多甜就有多痛', '再多努力'],
#  ['再多努力', '也换不来永恒的爱情'],
#  ['也换不来永恒的爱情', '男人三十'],
#  ['男人三十', '别想你'],
#  ['别想你', '忍不住我提醒自己'],
#  ['忍不住我提醒自己', '伤了心'],
#  ['伤了心', '有些事也要过去'],
#  ['有些事也要过去', '心很痛'],
#  ['心很痛', '痛的不想再做我自己'],
#  ['痛的不想再做我自己', '别回头'],
#  ['别回头', '情已去缘已尽'],
#  ['情已去缘已尽', '很想你'],
#  ['很想你', '也不是因为失去你'],
#  ['也不是因为失去你', '爱了你'],
#  ['爱了你', '用尽我全心全力'],
#  ['用尽我全心全力', '一生情'],
#  ['一生情', '只为这一次与你相遇'],
#  ['只为这一次与你相遇', '情难了'],
#  ['情难了', '难再续'],
#  ['难再续', '难再醒'],
#  ['难再醒', '人分飞'],
#  ['人分飞', '爱相随'],
#  ['爱相随', '哪怕用一生去追'],
#  ['哪怕用一生去追', '我又怎么能追得回'],
#  ['我又怎么能追得回', '与你相慰'],
#  ['与你相慰', '我为你痴'],
#  ['我为你痴', '为你累'],
#  ['为你累', '风雨我都不后悔'],
#  ['风雨我都不后悔', '我又怎么有路可退'],
#  ['我又怎么有路可退', '曾经深情'],
#  ['曾经深情', '你给了谁'],
#  ['你给了谁', '很想你'],
#  ['很想你', '也不是因为失去你'],
#  ['也不是因为失去你', '爱了你'],
#  ['爱了你', '用尽我全心全力'],
#  ['用尽我全心全力', '一生情'],
#  ['一生情', '只为这一次与你相遇'],
#  ['只为这一次与你相遇', '情难了'],
#  ['情难了', '难再续'],
#  ['难再续', '难再醒'],
#  ['难再醒', '人分飞'],
#  ['人分飞', '爱相随'],
#  ['爱相随', '哪怕用一生去追'],
#  ['哪怕用一生去追', '我又怎么能追得回'],
#  ['我又怎么能追得回', '与你相慰'],
#  ['与你相慰', '我为你痴'],
#  ['我为你痴', '为你累'],
#  ['为你累', '风雨我都不后悔'],
#  ['风雨我都不后悔', '我又怎么有路可退'],
#  ['我又怎么有路可退', '我如何面对'],
#  ['我如何面对', '人分飞'],
#  ['人分飞', '爱相随'],
#  ['爱相随', '哪怕用一生去追'],
#  ['哪怕用一生去追', '我又怎么能追得回'],
#  ['我又怎么能追得回', '与你相慰'],
#  ['与你相慰', '我为你痴'],
#  ['我为你痴', '为你累'],
#  ['为你累', '风雨我都不后悔'],
#  ['风雨我都不后悔', '我又怎么有路可退'],
#  ['我又怎么有路可退', '笑笑离开'],
#  ['笑笑离开', '刘依纯'],
#  ['刘依纯', '笑笑离开'],
#  ['笑笑离开', '刘依纯'],
#  ['刘依纯', '笑笑离开'],
#  ['笑笑离开', '明知不该爱的人'],
#  ['明知不该爱的人', '心里又搁不愿放'],
#  ['心里又搁不愿放', '等待一种无聊的希望'],
#  ['等待一种无聊的希望', '一段不愿醒的梦'],
#  ['一段不愿醒的梦', '最后换来一场空'],
#  ['最后换来一场空', '有谁人会冻知影阮苦痛'],
#  ['有谁人会冻知影阮苦痛', '你要我含着眼屎'],
#  ['你要我含着眼屎', '忍着痛苦陪你陪到这'],
#  ['忍着痛苦陪你陪到这', '你麦搁越头看'],
#  ['你麦搁越头看', '乎悲伤留底这'],
#  ['乎悲伤留底这', '你要我放舍过去'],
#  ['你要我放舍过去', '笑笑离开我会冻讲啥'],
#  ['笑笑离开我会冻讲啥', '爱只剩祝福我'],
#  ['爱只剩祝福我', '爱恨抹冻由我'],
#  ['爱恨抹冻由我', '彩云曲'],
#  ['彩云曲', '雷安娜聚散太匆匆'],
#  ['雷安娜聚散太匆匆', '曾在我心中飘过'],
#  ['曾在我心中飘过', '不要问他是谁人'],
#  ['不要问他是谁人', '虽说是'],
#  ['虽说是', '人生散聚也匆匆'],
#  ['人生散聚也匆匆', '他的印象实太深'],
#  ['他的印象实太深', '曾愿意终生依托'],
#  ['曾愿意终生依托', '他却像天外流云'],
#  ['他却像天外流云', '深惜是'],
#  ['深惜是', '萍水再遇也匆匆'],
#  ['萍水再遇也匆匆', '心中渴望难自禁'],
#  ['心中渴望难自禁', '风里立'],
#  ['风里立', '不管天已暗'],
#  ['不管天已暗', '为了他'],
#  ['为了他', '不管寒意侵'],
#  ['不管寒意侵', '早知道'],
#  ['早知道', '天地茫茫无觅处'],
#  ['天地茫茫无觅处', '如倦鸟正想归去'],
#  ['如倦鸟正想归去', '他却在灯下重临'],
#  ['他却在灯下重临', '古道萍水偶遇太匆匆'],
#  ['古道萍水偶遇太匆匆', '心中各自留下印'],
#  ['心中各自留下印', '风里立'],
#  ['风里立', '不管天已暗'],
#  ['不管天已暗', '为了他'],
#  ['为了他', '不管寒意侵'],
#  ['不管寒意侵', '早知道'],
#  ['早知道', '天地茫茫无觅处'],
#  ['天地茫茫无觅处', '如倦鸟正想归去'],
#  ['如倦鸟正想归去', '他却在灯下重临'],
#  ['他却在灯下重临', '古道萍水偶遇太匆匆'],
#  ['古道萍水偶遇太匆匆', '心中各自留下印'],
#  ['心中各自留下印', '演唱会'],
#  ['演唱会', '原来你这样珍惜我'],
#  ['原来你这样珍惜我', '从前在热恋中都未听讲过'],
#  ['从前在热恋中都未听讲过', '别说这种行货'],
#  ['别说这种行货', '哪里留得住我'],
#  ['哪里留得住我', '到底是为什么分手你很清楚'],
#  ['到底是为什么分手你很清楚', '如何笨到底'],
#  ['如何笨到底', '但到底还是我'],
#  ['但到底还是我', '谁人待我好'],
#  ['谁人待我好', '待我差'],
#  ['待我差', '太清楚'],
#  ['太清楚', '想继续装傻'],
#  ['想继续装傻', '却又无力受折磨'],
#  ['却又无力受折磨', '心里羡慕那些人'],
#  ['心里羡慕那些人', '盲目到不计后果'],
#  ['盲目到不计后果', '我就回去'],
#  ['我就回去', '别引出我泪水'],
#  ['别引出我泪水', '尤其明知水瓶座最爱是流泪'],
#  ['尤其明知水瓶座最爱是流泪', '若然道别是下一句'],
#  ['若然道别是下一句', '请你闭上了你的嘴'],
#  ['请你闭上了你的嘴', '无谓再会要是再会更加心碎'],
#  ['无谓再会要是再会更加心碎', '要是回去没有止痛药水'],
#  ['要是回去没有止痛药水', '拿来长岛冰茶换我半晚安睡'],
#  ['拿来长岛冰茶换我半晚安睡', '十年后或现在失去'],
#  ['十年后或现在失去', '反正到最尾也唏嘘'],
#  ['反正到最尾也唏嘘', '璇曲蔓地'],
#  ['璇曲蔓地', '难忘今宵'],
#  ['难忘今宵', '难忘今宵'],
#  ['难忘今宵', '无论天涯与海角'],
#  ['无论天涯与海角', '神州万里同怀抱'],
#  ['神州万里同怀抱', '共祝愿'],
#  ['共祝愿', '祖国好'],
#  ['祖国好', '祖国好'],
#  ['祖国好', '共祝愿'],
#  ['共祝愿', '祖国好'],
#  ['祖国好', '共祝愿'],
#  ['共祝愿', '祖国好'],
#  ['祖国好', '告别今宵'],
#  ['告别今宵', '告别今宵'],
#  ['告别今宵', '无论新友与故交'],
#  ['无论新友与故交', '明年春来再相邀'],
#  ['明年春来再相邀', '青山在'],
#  ['青山在', '人未老'],
#  ['人未老', '人未老'],
#  ['人未老', '青山在'],
#  ['青山在', '人未老'],
#  ['人未老', '青山在'],
#  ['青山在', '人未老'],
#  ['人未老', '难忘今宵'],
#  ['难忘今宵', '难忘今宵'],
#  ['难忘今宵', '无论天涯与海角'],
#  ['无论天涯与海角', '神州万里同怀抱'],
#  ['神州万里同怀抱', '共祝愿祖国好'],
#  ['共祝愿祖国好', '祖国好'],
#  ['祖国好', '共祝愿'],
#  ['共祝愿', '祖国好'],
#  ['祖国好', '滑步向左'],
#  ['滑步向左', '王雪娥'],
#  ['王雪娥', '滑步向左'],
#  ['滑步向左', '词'],
#  ['词', '曲王治平'],
#  ['曲王治平', '看见你我就充满活力'],
#  ['看见你我就充满活力', '我不能抗拒你'],
#  ['我不能抗拒你', '的眼神'],
#  ['的眼神', '不要离开我'],
#  ['不要离开我', '跳舞像闪电的功力无人能比'],
#  ['跳舞像闪电的功力无人能比', '我滑步向左'],
#  ['我滑步向左', '你转身向右'],
#  ['你转身向右', '环绕着你我'],
#  ['环绕着你我', '我转身向左'],
#  ['我转身向左', '你扭腰向右'],
#  ['你扭腰向右', '再一段'],
#  ['再一段', '看见你我就无能为力'],
#  ['看见你我就无能为力', '我不能抗拒你跳舞的姿势'],
#  ['我不能抗拒你跳舞的姿势', '不要离开我'],
#  ['不要离开我', '人潮拥挤'],
#  ['人潮拥挤', '唯独你在我的眼里'],
#  ['唯独你在我的眼里', '小螺号'],
#  ['小螺号', '李志'],
#  ['李志', '小螺号滴滴滴吹'],
#  ['小螺号滴滴滴吹', '海鸥听了展翅飞'],
#  ['海鸥听了展翅飞', '小螺号滴滴滴吹'],
#  ['小螺号滴滴滴吹', '浪花听了笑微微'],
#  ['浪花听了笑微微', '小螺号滴滴滴吹'],
#  ['小螺号滴滴滴吹', '声声唤船归'],
#  ['声声唤船归', '小螺号滴滴滴吹'],
#  ['小螺号滴滴滴吹', '阿爸听了快快回'],
#  ['阿爸听了快快回', '茫茫的海滩'],
#  ['茫茫的海滩', '蓝蓝的海水'],
#  ['蓝蓝的海水', '吹起了螺号'],
#  ['吹起了螺号', '心里美'],
#  ['心里美', '小螺号滴滴滴吹'],
#  ['小螺号滴滴滴吹', '海鸥听了展翅飞'],
#  ['海鸥听了展翅飞', '小螺号滴滴滴吹'],
#  ['小螺号滴滴滴吹', '浪花听了笑微微'],
#  ['浪花听了笑微微', '小螺号滴滴滴吹'],
#  ['小螺号滴滴滴吹', '声声唤船归'],
#  ['声声唤船归', '小螺号滴滴滴吹'],
#  ['小螺号滴滴滴吹', '阿爸听了快快回'],
#  ['阿爸听了快快回', '茫茫的海滩'],
#  ['茫茫的海滩', '蓝蓝的海水'],
#  ['蓝蓝的海水', '吹起了螺号'],
#  ['吹起了螺号', '心里美'],
#  ['心里美', '茫茫的海滩'],
#  ['茫茫的海滩', '蓝蓝的海水'],
#  ['蓝蓝的海水', '吹起了螺号'],
#  ['吹起了螺号', '心里美'],
#  ['心里美', '火红的妹妹'],
#  ['火红的妹妹', '肖亮'],
#  ['肖亮', '吉时雨'],
#  ['吉时雨', '火红的妹妹'],
#  ['火红的妹妹', '演唱肖亮'],
#  ['演唱肖亮', '发行北京博艺唱片'],
#  ['发行北京博艺唱片', '吉时雨'],
#  ['吉时雨', '天边的大雁往北飞'],
#  ['天边的大雁往北飞', '树上的鸟儿成双对'],
#  ['树上的鸟儿成双对', '唱一曲山歌是心里美呀'],
#  ['唱一曲山歌是心里美呀', '一碗美酒好滋味'],
#  ['一碗美酒好滋味', '飞舞的落花随流水'],
#  ['飞舞的落花随流水', '花间的蝴蝶你翩翩飞'],
#  ['花间的蝴蝶你翩翩飞', '心爱的妹妹来相依偎呀'],
#  ['心爱的妹妹来相依偎呀', '走到天涯永相随'],
#  ['走到天涯永相随', '火红的妹妹你火红的嘴'],
#  ['火红的妹妹你火红的嘴', '火红的花儿你吐花蕊'],
#  ['火红的花儿你吐花蕊', '火红的日子我把你陪'],
#  ['火红的日子我把你陪', '在我心你最珍贵'],
#  ['在我心你最珍贵', '火红的妹妹你火红的嘴'],
#  ['火红的妹妹你火红的嘴', '火红的脸庞你多妩媚'],
#  ['火红的脸庞你多妩媚', '火红的爱情我把你追呀'],
#  ['火红的爱情我把你追呀', '爱上你我今生无悔'],
#  ['爱上你我今生无悔', '不老情歌'],
#  ['不老情歌', '粤夜粤美丽'],
#  ['粤夜粤美丽', '谁伴谁漫漫长夜灯光影里'],
#  ['谁伴谁漫漫长夜灯光影里', '私私低语到天明'],
#  ['私私低语到天明', '齐共度梦想于深宵'],
#  ['齐共度梦想于深宵', '爱意透露两心知'],
#  ['爱意透露两心知', '任何事随时随地陪着你'],
#  ['任何事随时随地陪着你', '经历年岁月'],
#  ['经历年岁月', '尽流露内心的爱意'],
#  ['尽流露内心的爱意', '这份缘未完'],
#  ['这份缘未完', '可知道从前情迷乱身边的爱'],
#  ['可知道从前情迷乱身边的爱', '今天一切变安宁'],
#  ['今天一切变安宁', '如站立雾中分不清'],
#  ['如站立雾中分不清', '季节去后已清醒'],
#  ['季节去后已清醒', '可再否同行同步同渡过'],
#  ['可再否同行同步同渡过', '他日遥远路'],
#  ['他日遥远路', '让承诺实践这契约'],
#  ['让承诺实践这契约', '今夜情为证'],
#  ['今夜情为证', '齐延续怀内热爱再适应'],
#  ['齐延续怀内热爱再适应', '你我再轻拥看今夕'],
#  ['你我再轻拥看今夕', '生活如流水般冲擦掠过'],
#  ['生活如流水般冲擦掠过', '一生相爱永珍惜'],
#  ['一生相爱永珍惜', '同燃亮熊熊热爱两感应'],
#  ['同燃亮熊熊热爱两感应', '你我应欣赏每一夕'],
#  ['你我应欣赏每一夕', '生活如流水般冲擦掠过'],
#  ['生活如流水般冲擦掠过', '一生相爱只属你'],
#  ['一生相爱只属你', '可知道从前情迷乱身边的爱'],
#  ['可知道从前情迷乱身边的爱', '今天一切变安宁'],
#  ['今天一切变安宁', '如站立雾中分不清'],
#  ['如站立雾中分不清', '季节去后已清醒'],
#  ['季节去后已清醒', '可再否同行同步同渡过'],
#  ['可再否同行同步同渡过', '他日遥远路'],
#  ['他日遥远路', '让承诺实践这契约'],
#  ['让承诺实践这契约', '今夜情为证'],
#  ['今夜情为证', '齐延续怀内热爱再适应'],
#  ['齐延续怀内热爱再适应', '你我再轻拥看今夕'],
#  ['你我再轻拥看今夕', '生活如流水般冲擦掠过'],
#  ['生活如流水般冲擦掠过', '一生相爱永珍惜'],
#  ['一生相爱永珍惜', '同燃亮熊熊热爱两感应'],
#  ['同燃亮熊熊热爱两感应', '你我应欣赏每一夕'],
#  ['你我应欣赏每一夕', '生活如流水般冲擦掠过'],
#  ['生活如流水般冲擦掠过', '一生相爱只属你'],
#  ['一生相爱只属你', '齐延续怀内热爱再适应'],
#  ['齐延续怀内热爱再适应', '你我再轻拥看今夕'],
#  ['你我再轻拥看今夕', '生活如流水般冲擦掠过'],
#  ['生活如流水般冲擦掠过', '一生相爱永珍惜'],
#  ['一生相爱永珍惜', '同燃亮熊熊热爱两感应'],
#  ['同燃亮熊熊热爱两感应', '你我应欣赏每一夕'],
#  ['你我应欣赏每一夕', '生活如流水般冲擦掠过'],
#  ['生活如流水般冲擦掠过', '一生相爱只属你'],
#  ['一生相爱只属你', '当两颗心开始震动'],
#  ['当两颗心开始震动', '当你瞳孔学会闪躲'],
#  ['当你瞳孔学会闪躲', '当爱慢慢被遮住只剩下黑'],
#  ['当爱慢慢被遮住只剩下黑', '距离像影子被拉拖'],
#  ['距离像影子被拉拖', '当爱的故事剩听说'],
#  ['当爱的故事剩听说', '我找不到你单纯的面孔'],
#  ['我找不到你单纯的面孔', '当生命每分每秒都为你转动'],
#  ['当生命每分每秒都为你转动', '心多执着就加倍心痛'],
#  ['心多执着就加倍心痛', '那些你很冒险的梦'],
#  ['那些你很冒险的梦', '我陪你去疯'],
#  ['我陪你去疯', '折纸飞机'],
#  ['折纸飞机', '碰到雨天'],
#  ['碰到雨天', '终究会坠落'],
#  ['终究会坠落', '太残忍的话我直说'],
#  ['太残忍的话我直说', '因为爱很重'],
#  ['因为爱很重', '你却不想懂'],
#  ['你却不想懂', '只往反方向走'],
#  ['只往反方向走', '当爱的故事剩听说'],
#  ['当爱的故事剩听说', '我找不到你单纯的面孔'],
#  ['我找不到你单纯的面孔', '当生命每分每秒都为你转动'],
#  ['当生命每分每秒都为你转动', '心有多执着就加倍心痛'],
#  ['心有多执着就加倍心痛', '那些你很冒险的梦'],
#  ['那些你很冒险的梦', '我陪你去疯'],
#  ['我陪你去疯', '折纸飞机'],
#  ['折纸飞机', '碰到雨天'],
#  ['碰到雨天', '终究会坠落'],
#  ['终究会坠落', '太残忍的话我直说'],
#  ['太残忍的话我直说', '因为爱很重'],
#  ['因为爱很重', '你却不想懂'],
#  ['你却不想懂', '只往反方向走'],
#  ['只往反方向走', '我不想放手'],
#  ['我不想放手', '你松开的左手'],
#  ['你松开的左手', '你爱的放纵'],
#  ['你爱的放纵', '我白不回天空'],
#  ['我白不回天空', '我输了'],
#  ['我输了', '累了'],
#  ['累了', '当你'],
#  ['当你', '再也'],
#  ['再也', '不回头'],
#  ['不回头', '那些你很冒险的梦'],
#  ['那些你很冒险的梦', '我陪你去疯'],
#  ['我陪你去疯', '折纸飞机'],
#  ['折纸飞机', '碰到雨天'],
#  ['碰到雨天', '终究会坠落'],
#  ['终究会坠落', '太残忍的话我直说'],
#  ['太残忍的话我直说', '因为爱很重'],
#  ['因为爱很重', '你却不想懂'],
#  ['你却不想懂', '只往反方向走'],
#  ['只往反方向走', '你真的不懂'],
#  ['你真的不懂', '我的爱已降落'],
#  ['我的爱已降落', '未来的守望者'],
#  ['未来的守望者', '罗嘉良'],
#  ['罗嘉良', '未来的守望者'],
#  ['未来的守望者', '卫斯理'],
#  ['卫斯理', '银河像雾'],
#  ['银河像雾', '变化无穷'],
#  ['变化无穷', '偏想看'],
#  ['偏想看', '第二片天空'],
#  ['第二片天空', '玄玄幻幻'],
#  ['玄玄幻幻', '跌入迷宫'],
#  ['跌入迷宫', '看着时间失控'],
#  ['看着时间失控', '光与影再不相逢'],
#  ['光与影再不相逢', '尽化做奇梦'],
#  ['尽化做奇梦', '仍然放纵'],
#  ['仍然放纵', '浮世'],
#  ['浮世', '任我掌控'],
#  ['任我掌控', '谁人能像我不断为梦幻喝彩'],
#  ['谁人能像我不断为梦幻喝彩', '而此刻始终相信有希望存在'],
#  ['而此刻始终相信有希望存在', '让我抱紧感觉'],
#  ['让我抱紧感觉', '就算看不见将来'],
#  ['就算看不见将来', '隔两个空间都可以相爱'],
#  ['隔两个空间都可以相爱', '谁人又像我执着梦幻没变改'],
#  ['谁人又像我执着梦幻没变改', '而此刻始终相信最好是期待'],
#  ['而此刻始终相信最好是期待', '用半生精彩'],
#  ['用半生精彩', '来埋没感慨'],
#  ['来埋没感慨', '横渡那星海'],
#  ['横渡那星海', '换一个未来'],
#  ['换一个未来', '陈心蕊'],
#  ['陈心蕊', '最美的花儿'],
#  ['最美的花儿', '最美的花儿'],
#  ['最美的花儿', '童心撞地球'],
#  ['童心撞地球', '陈金文'],
#  ['陈金文', '孙广山'],
#  ['孙广山', '李娓'],
#  ['李娓', '安徽汉马文化传媒有限公司'],
#  ['安徽汉马文化传媒有限公司', '最美的花儿'],
#  ['最美的花儿', '陈心蕊'],
#  ['陈心蕊', '斯兰'],
#  ['斯兰', '电影天使与毒蝎主题歌'],
#  ['电影天使与毒蝎主题歌', '女儿我是妈妈心头'],
#  ['女儿我是妈妈心头', '最美的花儿'],
#  ['最美的花儿', '四季轮回'],
#  ['四季轮回', '妈妈在牵挂呀'],
#  ['妈妈在牵挂呀', '血脉相依'],
#  ['血脉相依', '这份情义无价'],
#  ['这份情义无价', '心心相惜'],
#  ['心心相惜', '远离繁杂'],
#  ['远离繁杂', '幸福在我家'],
#  ['幸福在我家', '妈妈你是妈妈心头'],
#  ['妈妈你是妈妈心头', '最美的花儿'],
#  ['最美的花儿', '雨露阳光'],
#  ['雨露阳光', '都是爱的表达'],
#  ['都是爱的表达', '茁壮成长'],
#  ['茁壮成长', '昂首风吹雨打'],
#  ['昂首风吹雨打', '绚丽绽放'],
#  ['绚丽绽放', '圣洁无瑕'],
#  ['圣洁无瑕', '春晖满天涯'],
#  ['春晖满天涯', '女儿不忍看妈妈'],
#  ['女儿不忍看妈妈', '泪水染脸颊'],
#  ['泪水染脸颊', '女儿也有爱'],
#  ['女儿也有爱', '爱也很强大'],
#  ['爱也很强大', '让爱'],
#  ['让爱', '拥抱她'],
#  ['拥抱她', '抱紧她'],
#  ['抱紧她', '抱紧她'],
#  ['抱紧她', '妈妈不要让妈妈'],
#  ['妈妈不要让妈妈', '泪水满脸颊'],
#  ['泪水满脸颊', '撕裂的魔鬼我们绝不怕'],
#  ['撕裂的魔鬼我们绝不怕', '勇敢'],
#  ['勇敢', '战胜它'],
#  ['战胜它', '远离它'],
#  ['远离它', '远离它'],
#  ['远离它', '合爱在心底'],
#  ['合爱在心底', '生根发芽'],
#  ['生根发芽', '女儿幸福在我家'],
#  ['女儿幸福在我家', '妈妈春晖满天涯'],
#  ['妈妈春晖满天涯', '合盛开吧'],
#  ['合盛开吧', '最美的花儿'],
#  ['最美的花儿', '妈妈你是妈妈心头'],
#  ['妈妈你是妈妈心头', '最美的花儿'],
#  ['最美的花儿', '雨露阳光'],
#  ['雨露阳光', '都是爱的表达'],
#  ['都是爱的表达', '茁壮成长'],
#  ['茁壮成长', '昂首风吹雨打'],
#  ['昂首风吹雨打', '绚丽绽放'],
#  ['绚丽绽放', '圣洁无瑕'],
#  ['圣洁无瑕', '春晖满天涯'],
#  ['春晖满天涯', '女儿不忍看妈妈'],
#  ['女儿不忍看妈妈', '泪水染脸颊'],
#  ['泪水染脸颊', '女儿也有爱'],
#  ['女儿也有爱', '爱也很强大'],
#  ['爱也很强大', '让爱'],
#  ['让爱', '拥抱她'],
#  ['拥抱她', '抱紧她'],
#  ['抱紧她', '抱紧她'],
#  ['抱紧她', '妈妈不要让妈妈'],
#  ['妈妈不要让妈妈', '泪水满脸颊'],
#  ['泪水满脸颊', '撕裂的魔鬼我们绝不怕'],
#  ['撕裂的魔鬼我们绝不怕', '勇敢'],
#  ['勇敢', '战胜它'],
#  ['战胜它', '远离它'],
#  ['远离它', '远离它'],
#  ['远离它', '合爱在心底'],
#  ['合爱在心底', '生根发芽'],
#  ['生根发芽', '女儿幸福在我家'],
#  ['女儿幸福在我家', '妈妈春晖满天涯'],
#  ['妈妈春晖满天涯', '合盛开吧'],
#  ['合盛开吧', '最美的花儿'],
#  ['最美的花儿', '一生的最爱'],
#  ['一生的最爱', '郭小俊'],
#  ['郭小俊', '爱爱爱谁明白'],
#  ['爱爱爱谁明白', '艾艺楠'],
#  ['艾艺楠', '一生的最爱'],
#  ['一生的最爱', '郭小俊'],
#  ['郭小俊', '演唱郭小俊'],
#  ['演唱郭小俊', '我的爱是一团火'],
#  ['我的爱是一团火', '烧的很寂寞'],
#  ['烧的很寂寞', '你的爱是一个梦'],
#  ['你的爱是一个梦', '让我受折磨'],
#  ['让我受折磨', '离开你我好孤单'],
#  ['离开你我好孤单', '痴情最伤心'],
#  ['痴情最伤心', '别把我的心带走'],
#  ['别把我的心带走', '给我点温柔'],
#  ['给我点温柔', '你就是我一生中'],
#  ['你就是我一生中', '最爱的那一个人'],
#  ['最爱的那一个人', '我用一生时间等待'],
#  ['我用一生时间等待', '我爱你真的很认真'],
#  ['我爱你真的很认真', '你就是我一生中'],
#  ['你就是我一生中', '最爱的那一个人'],
#  ['最爱的那一个人', '我用一生来等待你'],
#  ['我用一生来等待你', '我爱你爱的真的很认真'],
#  ['我爱你爱的真的很认真', '我的爱是一团火'],
#  ['我的爱是一团火', '烧的很寂寞'],
#  ['烧的很寂寞', '你的爱是一个梦'],
#  ['你的爱是一个梦', '让我受折磨'],
#  ['让我受折磨', '离开你我好孤单'],
#  ['离开你我好孤单', '痴情最伤心'],
#  ['痴情最伤心', '别把我的心带走'],
#  ['别把我的心带走', '给我点温柔'],
#  ['给我点温柔', '你就是我一生中'],
#  ['你就是我一生中', '最爱的那一个人'],
#  ['最爱的那一个人', '我用一生时间等待'],
#  ['我用一生时间等待', '我爱你真的很认真'],
#  ['我爱你真的很认真', '你就是我一生中'],
#  ['你就是我一生中', '最爱的那一个人'],
#  ['最爱的那一个人', '我用一生来等待你'],
#  ['我用一生来等待你', '我爱你爱的真的很认真'],
#  ['我爱你爱的真的很认真', '你就是我一生中'],
#  ['你就是我一生中', '最爱的那一个人'],
#  ['最爱的那一个人', '我用一生时间等待'],
#  ['我用一生时间等待', '我爱你真的很认真'],
#  ['我爱你真的很认真', '你就是我一生中'],
#  ['你就是我一生中', '最爱的那一个人'],
#  ['最爱的那一个人', '我用一生来等待你'],
#  ['我用一生来等待你', '我爱你爱的真的很认真'],
#  ['我爱你爱的真的很认真', '杨柳像我家一般青绿'],
#  ['杨柳像我家一般青绿', '郑少秋'],
#  ['郑少秋', '楚留香'],
#  ['楚留香', '演唱郑少秋'],
#  ['演唱郑少秋', '迎着冷风是我自己在那海边送夕阳红'],
#  ['迎着冷风是我自己在那海边送夕阳红', '杨柳青青一样垂下任冷风吹动'],
#  ['杨柳青青一样垂下任冷风吹动', '留在脑海在故梦中是我一家满面愁容'],
#  ['留在脑海在故梦中是我一家满面愁容', '离别那一刻心内沉重泪眼迷朦'],
#  ['离别那一刻心内沉重泪眼迷朦', '杨柳像我家一般青绿'],
#  ['杨柳像我家一般青绿', '异地垂杨常问我你有何美梦'],
#  ['异地垂杨常问我你有何美梦', '梦已空恨我自己恨往日天真寄望无穷'],
#  ['梦已空恨我自己恨往日天真寄望无穷', '谁料我今天身不知处再望见镜中有倦容'],
#  ['谁料我今天身不知处再望见镜中有倦容', '迎着冷风是我自己在那海边送夕阳红'],
#  ['迎着冷风是我自己在那海边送夕阳红', '杨柳青青一样垂下任冷风吹动'],
#  ['杨柳青青一样垂下任冷风吹动', '留在脑海在故梦中是我一家满面愁容'],
#  ['留在脑海在故梦中是我一家满面愁容', '离别那一刻心内沉重泪眼迷朦'],
#  ['离别那一刻心内沉重泪眼迷朦', '杨柳像我家一般青绿'],
#  ['杨柳像我家一般青绿', '异地垂杨常问我你有何美梦'],
#  ['异地垂杨常问我你有何美梦', '梦已空恨我自己恨往日天真寄望无穷'],
#  ['梦已空恨我自己恨往日天真寄望无穷', '谁料我今天身不知处再望见镜中有倦容'],
#  ['谁料我今天身不知处再望见镜中有倦容', '杨柳像我家一般青绿'],
#  ['杨柳像我家一般青绿', '异地垂杨常问我你有何美梦'],
#  ['异地垂杨常问我你有何美梦', '梦已空恨我自己恨往日天真'],
#  ['梦已空恨我自己恨往日天真', '寄望无穷谁料我今天身不知处'],
#  ['寄望无穷谁料我今天身不知处', '再望见镜中有倦容'],
#  ['再望见镜中有倦容', '轻轻晚风随意荡'],
#  ['轻轻晚风随意荡', '天色暗昏留悄静'],
#  ['天色暗昏留悄静', '月儿在半空'],
#  ['月儿在半空', '亮明划晚空'],
#  ['亮明划晚空', '远看心犹然望接触'],
#  ['远看心犹然望接触', '星星你可曾照亮'],
#  ['星星你可曾照亮', '心中爱火仍未亮'],
#  ['心中爱火仍未亮', '热情在我心'],
#  ['热情在我心', '熊熊是我心'],
#  ['熊熊是我心', '我说你因何寒傲似冰'],
#  ['我说你因何寒傲似冰', '莫再假装因眼眸已传情意'],
#  ['莫再假装因眼眸已传情意', '望你冲开心里面那道围墙'],
#  ['望你冲开心里面那道围墙', '你像风筝'],
#  ['你像风筝', '我像清风'],
#  ['我像清风', '扶助你放开胸怀冲天飞'],
#  ['扶助你放开胸怀冲天飞', '今天也许留印象'],
#  ['今天也许留印象', '他朝也许成幻象'],
#  ['他朝也许成幻象', '繁华愿放手'],
#  ['繁华愿放手', '性情未放手'],
#  ['性情未放手', '你却似依然从未放心'],
#  ['你却似依然从未放心', '莫再假装因眼眸已传情意'],
#  ['莫再假装因眼眸已传情意', '望你冲开心里面那道围墙'],
#  ['望你冲开心里面那道围墙', '你像风筝'],
#  ['你像风筝', '我像清风'],
#  ['我像清风', '扶助你放开胸怀冲天飞'],
#  ['扶助你放开胸怀冲天飞', '今天也许留印象'],
#  ['今天也许留印象', '他朝也许成幻象'],
#  ['他朝也许成幻象', '繁华愿放手'],
#  ['繁华愿放手', '性情未放手'],
#  ['性情未放手', '你却似依然从未放心'],
#  ['你却似依然从未放心', '热情在我心'],
#  ['热情在我心', '熊熊是我心'],
#  ['熊熊是我心', '我说你因何寒傲似冰'],
#  ['我说你因何寒傲似冰', '追爱'],
#  ['追爱', '张玮'],
#  ['张玮', '北上广不相信眼泪电视剧插曲'],
#  ['北上广不相信眼泪电视剧插曲', '周敏'],
#  ['周敏', '张玮'],
#  ['张玮', '追爱北上广不相信眼泪电视剧插曲'],
#  ['追爱北上广不相信眼泪电视剧插曲', '如果我差一句抱歉和玫瑰'],
#  ['如果我差一句抱歉和玫瑰', '能不能等靠近你'],
#  ['能不能等靠近你', '用拥抱还一个安慰'],
#  ['用拥抱还一个安慰', '雨的夜让你会怎么掉眼泪'],
#  ['雨的夜让你会怎么掉眼泪', '在门外的我擦肩过'],
#  ['在门外的我擦肩过', '这扇门有多少回'],
#  ['这扇门有多少回', '想与你挑战这个世界'],
#  ['想与你挑战这个世界', '才不问明天有多么冷冽'],
#  ['才不问明天有多么冷冽', '我不怕我多狼狈'],
#  ['我不怕我多狼狈', '就说一句就一句'],
#  ['就说一句就一句', '我爱你胜过一切'],
#  ['我爱你胜过一切', '将阻碍击得粉碎'],
#  ['将阻碍击得粉碎', '不管地球经纬'],
#  ['不管地球经纬', '一直走到遇见是因你而追'],
#  ['一直走到遇见是因你而追', '我爱你胜过一切'],
#  ['我爱你胜过一切', '虽然你也了解我也不完美'],
#  ['虽然你也了解我也不完美', '相信有一天'],
#  ['相信有一天', '与你的离别是生命的道别'],
#  ['与你的离别是生命的道别', '雨的夜让你会怎么掉眼泪'],
#  ['雨的夜让你会怎么掉眼泪', '在门外的我擦肩过'],
#  ['在门外的我擦肩过', '这扇门有多少回'],
#  ['这扇门有多少回', '想与你挑战这个世界'],
#  ['想与你挑战这个世界', '才不问明天有多么冷冽'],
#  ['才不问明天有多么冷冽', '我不怕我多狼狈'],
#  ['我不怕我多狼狈', '就说一句就一句'],
#  ['就说一句就一句', '我爱你胜过一切'],
#  ['我爱你胜过一切', '将阻碍击得粉碎'],
#  ['将阻碍击得粉碎', '不管地球经纬'],
#  ['不管地球经纬', '一直走到遇见是因你而追'],
#  ['一直走到遇见是因你而追', '我爱你胜过一切'],
#  ['我爱你胜过一切', '虽然你也了解我也不完美'],
#  ['虽然你也了解我也不完美', '相信有一天'],
#  ['相信有一天', '与你的离别是生命的道别'],
#  ['与你的离别是生命的道别', '我爱你胜过一切'],
#  ['我爱你胜过一切', '将阻碍击得粉碎'],
#  ['将阻碍击得粉碎', '不管地球经纬'],
#  ['不管地球经纬', '一直走到遇见是因你而追'],
#  ['一直走到遇见是因你而追', '我爱你胜过一切'],
#  ['我爱你胜过一切', '虽然你也了解我也不完美'],
#  ['虽然你也了解我也不完美', '相信有一天'],
#  ['相信有一天', '与你的离别是生命的道别'],
#  ['与你的离别是生命的道别', '不能离开你'],
#  ['不能离开你', '杨臣刚'],
#  ['杨臣刚', '老公老婆'],
#  ['老公老婆', '杨臣刚'],
#  ['杨臣刚', '不能离开你'],
#  ['不能离开你', '感觉你在我的梦里'],
#  ['感觉你在我的梦里', '已经不能再离开你'],
#  ['已经不能再离开你', '好象这样的感觉若即若离'],
#  ['好象这样的感觉若即若离', '消失在茫茫人海里'],
#  ['消失在茫茫人海里', '感觉你在我的心里'],
#  ['感觉你在我的心里', '已经不能再失去你'],
#  ['已经不能再失去你', '好想在每一天都拥抱着你'],
#  ['好想在每一天都拥抱着你', '让我在远方唿唤你'],
#  ['让我在远方唿唤你', '时间总是太短暂'],
#  ['时间总是太短暂', '感觉孤单'],
#  ['感觉孤单', '让我不能不想你'],
#  ['让我不能不想你', '只能在这梦境里'],
#  ['只能在这梦境里', '回想你曾经的欢笑'],
#  ['回想你曾经的欢笑', '让我无法忘记'],
#  ['让我无法忘记', '你曾经对我的好'],
#  ['你曾经对我的好', '感觉你在我的梦里'],
#  ['感觉你在我的梦里', '已经不能再离开你'],
#  ['已经不能再离开你', '好象这样的感觉若即若离'],
#  ['好象这样的感觉若即若离', '消失在茫茫人海里'],
#  ['消失在茫茫人海里', '宇宙最强'],
#  ['宇宙最强', '间中都会受伤'],
#  ['间中都会受伤', '有错处也正常'],
#  ['有错处也正常', '人和电脑亦会失常'],
#  ['人和电脑亦会失常', '碰着冷场'],
#  ['碰着冷场', '过几天再开张'],
#  ['过几天再开张', '尝败仗也别惆怅'],
#  ['尝败仗也别惆怅', '顺势放假休养'],
#  ['顺势放假休养', '当作间中机件故障'],
#  ['当作间中机件故障', '抽奖券怎会每次也抽中奖'],
#  ['抽奖券怎会每次也抽中奖', '每次野餐也遇上灿烂太阳'],
#  ['每次野餐也遇上灿烂太阳', '得到最酸那葡萄没有怎样'],
#  ['得到最酸那葡萄没有怎样', '总可以酿一樽果酱'],
#  ['总可以酿一樽果酱', '为何运气定要跟住你'],
#  ['为何运气定要跟住你', '快乐和幸福怎会有保养'],
#  ['快乐和幸福怎会有保养', '凡事尽过力自觉舒畅'],
#  ['凡事尽过力自觉舒畅', '就算是有时候结果不理想'],
#  ['就算是有时候结果不理想', '表演过怎会次次搏到拍掌'],
#  ['表演过怎会次次搏到拍掌', '每次要恋爱就有漂亮对象'],
#  ['每次要恋爱就有漂亮对象', '打输了一仗其实没有怎样'],
#  ['打输了一仗其实没有怎样', '顶多搏命打多一仗'],
#  ['顶多搏命打多一仗', '停下再储备营养'],
#  ['停下再储备营养', '若这次赶不上'],
#  ['若这次赶不上', '谢霆锋演唱会'],
#  ['谢霆锋演唱会', '是我要进入我地狱'],
#  ['是我要进入我地狱', '别要'],
#  ['别要', '比我更恐怖'],
#  ['比我更恐怖', '别再去贩卖你天堂'],
#  ['别再去贩卖你天堂', '若你'],
#  ['若你', '不悄我眼光'],
#  ['不悄我眼光', '不要望'],
#  ['不要望', '几时由旁诉去引导我怎去做'],
#  ['几时由旁诉去引导我怎去做', '惨烈或是愉快亦是我与怒'],
#  ['惨烈或是愉快亦是我与怒', '活这么一次管与论说好不好'],
#  ['活这么一次管与论说好不好', '曝光'],
#  ['曝光', '曝光'],
#  ['曝光', '明日是如何风光请你走看着'],
#  ['明日是如何风光请你走看着', '从未冒着风险祝福我别阻挡'],
#  ['从未冒着风险祝福我别阻挡', '曝光'],
#  ['曝光', '曝光'],
#  ['曝光', '独家的珍贵风光闲人别张望'],
#  ['独家的珍贵风光闲人别张望', '无限量大未来盛况'],
#  ['无限量大未来盛况', '谁都想窥探天生渴望'],
#  ['谁都想窥探天生渴望', '若你有脚移你的玉步'],
#  ['若你有脚移你的玉步', '别要'],
#  ['别要', '跟我再跌倒'],
#  ['跟我再跌倒', '路再远也是我的错'],
#  ['路再远也是我的错', '若你'],
#  ['若你', '打算对我好'],
#  ['打算对我好', '请路'],
#  ['请路', '几时由旁诉去引导我怎去做'],
#  ['几时由旁诉去引导我怎去做', '惨烈或是愉快亦是我与怒'],
#  ['惨烈或是愉快亦是我与怒', '活这么一次管与论说好不好'],
#  ['活这么一次管与论说好不好', '曝光'],
#  ['曝光', '曝光'],
#  ['曝光', '明日是如何风光请你走看着'],
#  ['明日是如何风光请你走看着', '从未冒着风险祝福我别阻挡'],
#  ['从未冒着风险祝福我别阻挡', '暴光'],
#  ['暴光', '暴光'],
#  ['暴光', '独家的珍贵风光闲人别张望'],
#  ['独家的珍贵风光闲人别张望', '无限量大未来盛况'],
#  ['无限量大未来盛况', '谁都想窥探天生渴望'],
#  ['谁都想窥探天生渴望', '曝光'],
#  ['曝光', '曝光'],
#  ['曝光', '明日是如何风光请你走看着'],
#  ['明日是如何风光请你走看着', '从未冒着风险祝福我别阻挡'],
#  ['从未冒着风险祝福我别阻挡', '曝光'],
#  ['曝光', '曝光'],
#  ['曝光', '独家的珍贵风光闲人别张望'],
#  ['独家的珍贵风光闲人别张望', '无限量大未来盛况'],
#  ['无限量大未来盛况', '谁都想窥探天生渴望'],
#  ['谁都想窥探天生渴望', '曝光'],
#  ['曝光', '曝光'],
#  ['曝光', '明日是如何风光请你走看着'],
#  ['明日是如何风光请你走看着', '从未冒着风险祝福我别阻挡'],
#  ['从未冒着风险祝福我别阻挡', '曝光'],
#  ['曝光', '曝光'],
#  ['曝光', '独家的珍贵风光闲人别张望'],
#  ['独家的珍贵风光闲人别张望', '无限量大未来盛况'],
#  ['无限量大未来盛况', '小幸福'],
#  ['小幸福', '郭心雨'],
#  ['郭心雨', '冰凝'],
#  ['冰凝', '缘轩'],
#  ['缘轩', '晓枫音乐'],
#  ['晓枫音乐', '童心撞地球'],
#  ['童心撞地球', '小幸福'],
#  ['小幸福', '演唱郭心雨'],
#  ['演唱郭心雨', '蓝天是我的一块画布'],
#  ['蓝天是我的一块画布', '画一个七彩太阳心里住'],
#  ['画一个七彩太阳心里住', '画一片白云像瀑布'],
#  ['画一片白云像瀑布', '弯弯的月亮还有一棵树'],
#  ['弯弯的月亮还有一棵树', '可爱的家是我最美的图'],
#  ['可爱的家是我最美的图', '画一个娃娃穿上新衣服'],
#  ['画一个娃娃穿上新衣服', '画一张床是我的小屋'],
#  ['画一张床是我的小屋', '爸妈给我温暖的呵护'],
#  ['爸妈给我温暖的呵护', '我也有我的小幸福'],
#  ['我也有我的小幸福', '有同学的陪伴我不孤独'],
#  ['有同学的陪伴我不孤独', '有爸妈的疼爱我不会哭'],
#  ['有爸妈的疼爱我不会哭', '可爱的家是我最美的图'],
#  ['可爱的家是我最美的图', '画一个娃娃穿上新衣服'],
#  ['画一个娃娃穿上新衣服', '画一张床是我的小屋'],
#  ['画一张床是我的小屋', '爸妈给我温暖的呵护'],
#  ['爸妈给我温暖的呵护', '我也有我的小幸福'],
#  ['我也有我的小幸福', '白天开心走过上学的小路'],
#  ['白天开心走过上学的小路', '夜晚进入梦乡把星星数'],
#  ['夜晚进入梦乡把星星数', '我也有我的小幸福'],
#  ['我也有我的小幸福', '有同学的陪伴我不孤独'],
#  ['有同学的陪伴我不孤独', '有爸妈的疼爱我不会哭'],
#  ['有爸妈的疼爱我不会哭', '我也有我的小幸福'],
#  ['我也有我的小幸福', '白天开心走过上学的小路'],
#  ['白天开心走过上学的小路', '夜晚进入梦乡把星星数'],
#  ['夜晚进入梦乡把星星数', '夜晚进入梦乡把星星数'],
#  ['夜晚进入梦乡把星星数', '曾流行情歌虽则都继续播'],
#  ['曾流行情歌虽则都继续播', '可惜今天无缘一起高歌一趟'],
#  ['可惜今天无缘一起高歌一趟', '唱'],
#  ['唱', '没结果'],
#  ['没结果', '再合唱亦没结果'],
#  ['再合唱亦没结果', '明明以前是我傻'],
#  ['明明以前是我傻', '求求你姑息我'],
#  ['求求你姑息我', '填词人替我写出的痛楚'],
#  ['填词人替我写出的痛楚', '期望你开口唱吧'],
#  ['期望你开口唱吧', '合唱歌那可得我'],
#  ['合唱歌那可得我', '当初你抛开我'],
#  ['当初你抛开我', '我独唱一次认错'],
#  ['我独唱一次认错', '你为何麻木地高歌唱下去不理为何'],
#  ['你为何麻木地高歌唱下去不理为何', '消失的激情还要热播'],
#  ['消失的激情还要热播', '谁人仍然是你记住的一个'],
#  ['谁人仍然是你记住的一个', '失去的恋爱难以勉强'],
#  ['失去的恋爱难以勉强', '开一句声'],
#  ['开一句声', '听着情歌总能满足一秒遐想'],
#  ['听着情歌总能满足一秒遐想', '日后留恋你的声线'],
#  ['日后留恋你的声线', '恐怕未放下'],
#  ['恐怕未放下', '明日更不堪设想'],
#  ['明日更不堪设想', '而我不堪设想'],
#  ['而我不堪设想', '一千句'],
#  ['一千句', '亲爱的'],
#  ['亲爱的', '恐怕时间到了无缘又遇上'],
#  ['恐怕时间到了无缘又遇上', '我亦无办法得到见谅'],
#  ['我亦无办法得到见谅', '忘掉我声音以后别惆怅'],
#  ['忘掉我声音以后别惆怅', '沉默一刻我在惆怅'],
#  ['沉默一刻我在惆怅', '始终无法合唱'],
#  ['始终无法合唱', '祈求回头亦太难'],
#  ['祈求回头亦太难', '如何唱多一晚'],
#  ['如何唱多一晚', '无人饶恕我比悲歌更惨'],
#  ['无人饶恕我比悲歌更惨', '其实你分手以后'],
#  ['其实你分手以后', '这一天已心淡'],
#  ['这一天已心淡', '当初你'],
#  ['当初你', '抛开我'],
#  ['抛开我', '我独唱一次'],
#  ['我独唱一次', '认错'],
#  ['认错', '你为何麻木地高歌'],
#  ['你为何麻木地高歌', '消失的激情还要热播'],
#  ['消失的激情还要热播', '谁人仍然是你记住的一个'],
#  ['谁人仍然是你记住的一个', '失去的恋爱难以勉强'],
#  ['失去的恋爱难以勉强', '开一句声'],
#  ['开一句声', '听着情歌总能满足一秒遐想'],
#  ['听着情歌总能满足一秒遐想', '日后留恋你的声线'],
#  ['日后留恋你的声线', '恐怕未放下'],
#  ['恐怕未放下', '明日更不堪设想'],
#  ['明日更不堪设想', '而我不堪设想'],
#  ['而我不堪设想', '一千句'],
#  ['一千句', '亲爱的'],
#  ['亲爱的', '恐怕时间到了无缘又遇上'],
#  ['恐怕时间到了无缘又遇上', '我亦无办法得到见谅'],
#  ['我亦无办法得到见谅', '忘掉我声音以后别惆怅'],
#  ['忘掉我声音以后别惆怅', '沉默一刻我在惆怅'],
#  ['沉默一刻我在惆怅', '始终无法合唱'],
#  ['始终无法合唱', '你要试着放低我'],
#  ['你要试着放低我', '我怕我以后还是唱没结果已是结果'],
#  ['我怕我以后还是唱没结果已是结果', '以后得一个'],
#  ['以后得一个', '失去的恋爱难以勉强'],
#  ['失去的恋爱难以勉强', '开一句声'],
#  ['开一句声', '听着情歌总能满足一秒遐想'],
#  ['听着情歌总能满足一秒遐想', '日后留恋你的声线'],
#  ['日后留恋你的声线', '恐怕未放下'],
#  ['恐怕未放下', '明日更不堪设想'],
#  ['明日更不堪设想', '而我不堪设想'],
#  ['而我不堪设想', '一千句'],
#  ['一千句', '亲爱的'],
#  ['亲爱的', '恐怕时间到了无缘又遇上'],
#  ['恐怕时间到了无缘又遇上', '我亦无办法得到见谅'],
#  ['我亦无办法得到见谅', '忘掉我声音以后别惆怅'],
#  ['忘掉我声音以后别惆怅', '沉默一刻我在惆怅'],
#  ['沉默一刻我在惆怅', '始终无法合唱'],
#  ['始终无法合唱', '下雨天国语版'],
#  ['下雨天国语版', '曲'],
#  ['曲', '黄良升词'],
#  ['黄良升词', '廖莹如编'],
#  ['廖莹如编', '先自我介绍'],
#  ['先自我介绍', '关于名字以外的事'],
#  ['关于名字以外的事', '再这样下去'],
#  ['再这样下去', '会冲动地采取行动用力抱你'],
#  ['会冲动地采取行动用力抱你', '我有喜欢的权利'],
#  ['我有喜欢的权利', '没听过你说这不行'],
#  ['没听过你说这不行', '我有完美的计划'],
#  ['我有完美的计划', '对你想些快乐的事'],
#  ['对你想些快乐的事', '情就能勇往直前'],
#  ['情就能勇往直前', '我知道我完了'],
#  ['我知道我完了', '不会难为情'],
#  ['不会难为情', '爱没办法闷在我心里'],
#  ['爱没办法闷在我心里', '总有一天会长大成人'],
#  ['总有一天会长大成人', '你要相信我会负责任'],
#  ['你要相信我会负责任', '没有人喜欢一直等'],
#  ['没有人喜欢一直等', '怎知道我不是那个人'],
#  ['怎知道我不是那个人', '说你傻瓜是一种心疼'],
#  ['说你傻瓜是一种心疼', '丢个球等剧烈反应'],
#  ['丢个球等剧烈反应', '就知道你会辨解着急'],
#  ['就知道你会辨解着急', '爱我不坏'],
#  ['爱我不坏', '就是现在'],
#  ['就是现在', '我也可以讨论未来'],
#  ['我也可以讨论未来', '爱定下来'],
#  ['爱定下来', '无所不在'],
#  ['无所不在', '爱我不坏'],
#  ['爱我不坏', '我想你明白'],
#  ['我想你明白', '使点坏'],
#  ['使点坏', '那种坏'],
#  ['那种坏', '根本不坏'],
#  ['根本不坏', '最真心的微笑'],
#  ['最真心的微笑', '看起来多美好'],
#  ['看起来多美好', '心里面'],
#  ['心里面', '爱有多少'],
#  ['爱有多少', '嘿'],
#  ['嘿', '感觉得到'],
#  ['感觉得到', '自然又健康最可靠'],
#  ['自然又健康最可靠', '自信的活力不能少'],
#  ['自信的活力不能少', '外在美'],
#  ['外在美', '当然很好'],
#  ['当然很好', '嘿'],
#  ['嘿', '内在更重要'],
#  ['内在更重要', '每天都要吃苹果'],
#  ['每天都要吃苹果', '两天敷脸一次外加清除毛细孔'],
#  ['两天敷脸一次外加清除毛细孔', '不要因为美白就窝在家里头'],
#  ['不要因为美白就窝在家里头', '偶尔晒晒太阳不要变成白切肉'],
#  ['偶尔晒晒太阳不要变成白切肉', '记得书要读得多'],
#  ['记得书要读得多', '气质好一点'],
#  ['气质好一点', '也是美容的一种'],
#  ['也是美容的一种', '我立下志愿'],
#  ['我立下志愿', '将来要环游世界'],
#  ['将来要环游世界', '还要用国语言把子曰读一遍'],
#  ['还要用国语言把子曰读一遍', '我要变美'],
#  ['我要变美', '不管外在或是内在美'],
#  ['不管外在或是内在美', '我要变美'],
#  ['我要变美', '一样都不能缺'],
#  ['一样都不能缺', '我要变美'],
#  ['我要变美', '变美以后去环游世界'],
#  ['变美以后去环游世界', '还要立志去环游世界'],
#  ['还要立志去环游世界', '我要变美'],
#  ['我要变美', '还要立志去环游世界'],
#  ['还要立志去环游世界', '我要变美'],
#  ['我要变美', '最好能有你陪'],
#  ...]

# %%
thulac.thulac(seg_only=True).cut('我们是相亲相爱的一家','ass')
list(list(zip(*thulac.thulac(seg_only=True).cut('我们是相亲相爱的一家')))[0])

# %%
def segment(data):
    import thulac
    cut_word = thulac.thulac(seg_only=True)
    seg_data = []
    for pair in data:
        seg_pair = []
        for string in pair:
            seg_pair.append(' '.join(list(list(zip(*cut_word.cut(string)))[0])))
        seg_data.append(seg_pair)
    return seg_data

# %%
segment(data)

# %%
# vocab = set()
# words = []
# for pair in data:
#     for string in pair:
#         words.append(string)
# split_sent = set(list(zip(*thulac.thulac(seg_only=True).cut(words)))[0])
# vocab.update(split_sent)

cut_word = thulac.thulac(seg_only=True)
vocab = set()
count = 0
for pair in data:
    for string in pair:
        
        split_sent = set(list(zip(*cut_word.cut(string)))[0])
        vocab.update(split_sent)
        count += 1
        #print(split_sent,count, '/', len(data))
# Out:
# Model loaded succeed

# %%
f = open("./resource/lyrics_vocab", "w", encoding = 'utf-8')
for word in vocab:
    f.write(word + '\n')
f.close()
